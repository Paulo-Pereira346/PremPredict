# %%
import pandas as pd
import glob 
import sklearn

# %%
path = "../data/processed/"
all_files = glob.glob(path + /*.csv)
# Out:
#    season  matchweek               team  overall_pos  overall_wins  \
# 0    2015         25     Leicester City            1            15
# 1    2015         25  Tottenham Hotspur            2            13
# 2    2015         25            Arsenal            3            14
# 3    2015         25    Manchester City            4            14
# 4    2015         25  Manchester United            5            11
#
#    overall_loss  overall_draws  overall_points  overall_played  overall_gf  \
# 0             2              8              53              25          47
# 1             3              9              48              25          45
# 2             5              6              48              25          39
# 3             6              5              47              25          47
# 4             6              8              41              25          32
#
#    ...  away_pos  away_wins  away_loss  away_draws  away_points  away_played  \
# ...
